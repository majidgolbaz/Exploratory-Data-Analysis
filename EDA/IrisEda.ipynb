# %% [markdown]
# Exploratory Data Analysis Python Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from seaborn import load_dataset

iris = sns,load_dataset('iris')
heart = pd.read_csv('E:/learning/UT DataScience/Python for Data Science/Session 1/Heart data.csv')
bnb = pd.read_csv('E:/learning/UT DataScience/Python for Data Science/datasets/AB_NYC_2019.csv' )

# %% [markdown]
# 1. Summary tools

# %%
from summarytools import dfSummary


iris = sns.load_dataset('iris')
dfSummary(iris)
# Out:
# <style type="text/css">
# #T_adcc3 thead>tr>th {
#   text-align: left;
# }
# #T_adcc3_row0_col0, #T_adcc3_row1_col0, #T_adcc3_row2_col0, #T_adcc3_row3_col0, #T_adcc3_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_adcc3_row0_col1, #T_adcc3_row1_col1, #T_adcc3_row2_col1, #T_adcc3_row3_col1, #T_adcc3_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_adcc3_row0_col2, #T_adcc3_row1_col2, #T_adcc3_row2_col2, #T_adcc3_row3_col2, #T_adcc3_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_adcc3_row0_col3, #T_adcc3_row1_col3, #T_adcc3_row2_col3, #T_adcc3_row3_col3, #T_adcc3_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
# ...

# %% [markdown]
# 2. Pandas Profiling or yData Profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(heart, title='Pandas Profiling Report', dark_mode= True )
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-07-22 07:12:06.038132&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @import url(&quot;https://fonts.googleapis.com/css?family=Lato:400,700,400italic&quot;);/*!
#  * bootswatch v3.3.7
#  * Homepage: http://bootswatch.com
#  * Copyright 2012-2016 Thomas Park
#  * Licensed under MIT
#  * Based on Bootstrap
# *//*!
# ...

# %% [markdown]
# 3. Sweetvis Package

# %%
# import sweetviz as sv

# my_report = sv.analyze(bnb)
# my_report.show_html()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import sweetviz as sv
#       3 my_report = sv.analyze(bnb)
#       4 my_report.show_html()
#
# ModuleNotFoundError: No module named 'sweetviz'
